# %% [markdown]
# ### 10 Question Target

# %% [markdown]
# 1.  Liner Search
# 2.  Largest in Array
# 3.  Binary Search
# 4.  Reverse an Array
# 5.  Pairs in Array
# 6.  Print Sub array
# 7.  Max SubArr Sum - I (Brute Force)
# 8.  Max SubArr Sum - II (Prefix Sum)
# 9. Max SubArr Sum - sum += numbers[j]
# 10.  Max SubArr Sum - III (Kadane's Algorithm)
# 11.  Max SubArr Sum all negative + kadane's
# 12. max sub arr sum + kadane's + sub arr
# 13. max sub arr product (*)
# 14.  Trapping Rainwater
# 15.  Best Time to Buy & Sell Stock

# %% [markdown]
# ### 10 Question Target

# %% [markdown]
# 01. Bubble Sort
# 02. Selection Sort
# 03. Insertion Sort
# 04. Counting Sort

# %% [markdown]
# import java.util.Arrays;
#
# import java.util.Collections; // collection work only object - (Integer, Character)
#
# // inbuilt sorting function
# int arr[] = {3,6,2,7,8};
#
# Arrays.sort(arr); // ascending order
#
# Arrays.sort(arr, Collections.reverseOrder()); // Descending order
#
# Arrays.sort(arr, startIndex, endIndex);

# %% [markdown]
# ### 10 Question Target

# %% [markdown]
# 01. Spiral Matrix
# 02. Diagonal Sum
# 03. Search in Sorted Matrix
